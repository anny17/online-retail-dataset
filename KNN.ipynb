# %% [markdown]
# <a href="https://colab.research.google.com/github/anny17/online-retail-dataset/blob/master/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Working on online reatail dataset

# %%
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
import io

# %%
import seaborn as sns

# %%
d=pd.read_csv("https://raw.githubusercontent.com/scheckley/online-retail/master/rfm-segments.csv")

# %%
d.shape
# Out:
# (4335, 8)

# %%
d.head(5)
# Out:
#    customer  frequency  recency  monetary_value  R_Quartile  F_Quartile  \
# 0   12346.0          1      325        77183.60           4           4
# 1   12347.0        182        2         4310.00           1           1
# 2   12348.0         27       75         1437.24           3           3
# 3   12349.0         72       18         1457.55           2           2
# 4   12350.0         16      310          294.40           4           4
#
#    M_Quartile  RFMClass
# 0           1       441
# 1           1       111
# 2           2       332
# 3           2       222
# 4           4       444

# %%
d.tail(10)
# Out:
#       customer  frequency  recency  monetary_value  R_Quartile  F_Quartile  \
# 4325   18273.0          3        2          204.00           1           4
# 4326   18274.0         11       30          175.92           2           4
# 4327   18276.0         14       43          335.86           2           4
# 4328   18277.0          8       58          110.38           3           4
# 4329   18278.0          9       73          173.90           3           4
# 4330   18280.0         10      277          180.60           4           4
# 4331   18281.0          7      180           80.82           4           4
# 4332   18282.0         12        7          178.05           1           4
# 4333   18283.0        719        3         2039.58           1           1
# 4334   18287.0         70       42         1837.28           2           2
#
#       M_Quartile  RFMClass
# 4325           4       144
# 4326           4       244
# 4327           3       243
# 4328           4       344
# ...

# %%
d.describe()
# Out:
#            customer    frequency      recency  monetary_value   R_Quartile  \
# count   4335.000000  4335.000000  4335.000000     4335.000000  4335.000000
# mean   15298.780392    90.268973    92.208535     2017.050436     2.494348
# std     1722.075082   225.205714   100.170816     8919.387033     1.121754
# min    12346.000000     1.000000     0.000000        0.000000     1.000000
# 25%    13811.500000    17.000000    17.000000      304.250000     1.000000
# 50%    15297.000000    41.000000    50.000000      663.610000     2.000000
# 75%    16778.500000    98.000000   142.000000     1631.475000     3.000000
# max    18287.000000  7667.000000   373.000000   279138.020000     4.000000
#
#         F_Quartile   M_Quartile     RFMClass
# count  4335.000000  4335.000000  4335.000000
# mean      2.515802     2.500346   277.093195
# std       1.122479     1.118472   118.360780
# min       1.000000     1.000000   111.000000
# 25%       2.000000     1.500000   144.000000
# ...

# %%
d.describe().transpose()
# Out:
#                  count          mean          std      min       25%  \
# customer        4335.0  15298.780392  1722.075082  12346.0  13811.50
# frequency       4335.0     90.268973   225.205714      1.0     17.00
# recency         4335.0     92.208535   100.170816      0.0     17.00
# monetary_value  4335.0   2017.050436  8919.387033      0.0    304.25
# R_Quartile      4335.0      2.494348     1.121754      1.0      1.00
# F_Quartile      4335.0      2.515802     1.122479      1.0      2.00
# M_Quartile      4335.0      2.500346     1.118472      1.0      1.50
# RFMClass        4335.0    277.093195   118.360780    111.0    144.00
#
#                      50%        75%        max
# customer        15297.00  16778.500   18287.00
# frequency          41.00     98.000    7667.00
# recency            50.00    142.000     373.00
# monetary_value    663.61   1631.475  279138.02
# R_Quartile          2.00      3.000       4.00
# F_Quartile          3.00      4.000       4.00
# ...

# %%
d.isnull().sum()
# Out:
# customer          0
# frequency         0
# recency           0
# monetary_value    0
# R_Quartile        0
# F_Quartile        0
# M_Quartile        0
# RFMClass          0
# dtype: int64

# %%
d['customer'].value_counts()
# Out:
# 17398.0    1
# 12731.0    1
# 17861.0    1
# 14146.0    1
# 13871.0    1
# 12710.0    1
# 15839.0    1
# 13485.0    1
# 16712.0    1
# 17166.0    1
# 15228.0    1
# 13986.0    1
# 12980.0    1
# 16469.0    1
# 17941.0    1
# 16690.0    1
# 17716.0    1
# 16747.0    1
# 14518.0    1
# 13589.0    1
# 15298.0    1
# 17450.0    1
# 14163.0    1
# 12617.0    1
# 17696.0    1
# 15644.0    1
# 15856.0    1
# 13960.0    1
# 13008.0    1
# 12458.0    1
#           ..
# 13132.0    1
# 16555.0    1
# 14753.0    1
# 13523.0    1
# 17926.0    1
# 17581.0    1
# 14270.0    1
# 14929.0    1
# 13658.0    1
# 16205.0    1
# 16566.0    1
# 14305.0    1
# 16713.0    1
# 15886.0    1
# 15096.0    1
# 13636.0    1
# 12648.0    1
# 12373.0    1
# 15939.0    1
# 14869.0    1
# 18043.0    1
# 12527.0    1
# 17962.0    1
# 17253.0    1
# 14642.0    1
# 13751.0    1
# 13174.0    1
# 17793.0    1
# 17779.0    1
# 12544.0    1
# Name: customer, Length: 4335, dtype: int64

# %%
d.dtypes
# Out:
# customer          float64
# frequency           int64
# recency             int64
# monetary_value    float64
# R_Quartile          int64
# F_Quartile          int64
# M_Quartile          int64
# RFMClass            int64
# dtype: object

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-ea516c22-0616-4290-9b67-c1a853084ee7" name="files[]" multiple disabled />
#      <output id="result-ea516c22-0616-4290-9b67-c1a853084ee7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving OnlineRetail.xlsx to OnlineRetail.xlsx
# User uploaded file "OnlineRetail.xlsx" with length 23715344 bytes

# %%
d = pd.read_excel("OnlineRetail.xlsx")

# %%
d.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
d.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
d.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
d.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
d.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
d['CustomerID'] = d.CustomerID.fillna(d.CustomerID.mean())

# %%
d.isnull().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description    1454
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID        0
# Country           0
# dtype: int64

# %%
d['Description'] = d.Description.fillna("Good")

# %%
pd.to_numeric(d, downcast='float')

# %%
d.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
values = d.drop(columns=['InvoiceNo','StockCode','Description','InvoiceDate','UnitPrice','Country'])

# %%
values
# Out:
#         Quantity  CustomerID
# 0            6.0     17850.0
# 1            6.0     17850.0
# 2            8.0     17850.0
# 3            6.0     17850.0
# 4            6.0     17850.0
# 5            2.0     17850.0
# 6            6.0     17850.0
# 7            6.0     17850.0
# 8            6.0     17850.0
# 9           32.0     13047.0
# 10           6.0     13047.0
# 11           6.0     13047.0
# 12           8.0     13047.0
# 13           6.0     13047.0
# 14           6.0     13047.0
# 15           3.0     13047.0
# 16           2.0     13047.0
# 17           3.0     13047.0
# 18           3.0     13047.0
# 19           4.0     13047.0
# 20           4.0     13047.0
# 21           6.0     13047.0
# 22           3.0     13047.0
# 23           3.0     13047.0
# 24           3.0     13047.0
# 25           3.0     13047.0
# 26          24.0     12583.0
# 27          24.0     12583.0
# 28          12.0     12583.0
# 29          12.0     12583.0
# ...          ...         ...
# ...

# %%
d['Quantity']=d.Quantity.astype(int)

# %%
d['CustomerID'] = d.CustomerID.astype(int)

# %%
d['UnitPrice'] = d.UnitPrice.astype(int)

# %%
d.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity              float64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
target = d.drop(columns=['InvoiceNo','StockCode','Description','InvoiceDate','Quantity','Country','CustomerID'])

# %%
values = d.drop(columns=['InvoiceNo','StockCode','Description','InvoiceDate','UnitPrice','Country'])

# %%
values
# Out:
#         Quantity  CustomerID
# 0              6       17850
# 1              6       17850
# 2              8       17850
# 3              6       17850
# 4              6       17850
# 5              2       17850
# 6              6       17850
# 7              6       17850
# 8              6       17850
# 9             32       13047
# 10             6       13047
# 11             6       13047
# 12             8       13047
# 13             6       13047
# 14             6       13047
# 15             3       13047
# 16             2       13047
# 17             3       13047
# 18             3       13047
# 19             4       13047
# 20             4       13047
# 21             6       13047
# 22             3       13047
# 23             3       13047
# 24             3       13047
# 25             3       13047
# 26            24       12583
# 27            24       12583
# 28            12       12583
# 29            12       12583
# ...          ...         ...
# ...

# %%
d
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10        536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11        536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(values,target,random_state=15,test_size=0.5)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neigh = KNeighborsClassifier(n_neighbors=2)

# %%
neigh.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#            weights='uniform')

# %%
p = neigh.score(x_test,y_test)

# %%
p
# Out:
# 0.33135022420697163
